# %%
from IPython.display import Image

# %% [markdown]
# # Expected Value and Variance

# %% [markdown]
# **Giá trị kỳ vọng của biến ngẫu nhiên** chính là trung bình trọng số xác suất các kết cục của biến ngẫu nhiên
#
# $$
# E(X) = \sum_{i=1}^{n}{P(X_i)X_i}
# $$
#
# **Phương sai của biến ngẫu nhiên** là giá trị kỳ vọng của bình phương độ lệch với giá trị kỳ vọng
#
# $$
# \sigma^2(X) = E(X-E(X))^2 = \sum_{i=1}^{n}{P(X_i)(X_i-E(X))^2}
# $$
#
# Trên thực tế, **độ lệch chuẩn** được ưa thích hơn phương sai, bởi nó có cùng đơn vị với biến ngẫu nhiên

# %% [markdown]
# # Probability Trees and Conditional Expectations

# %% [markdown]
# ## Conditional Expected Value
#
# Giá trị kỳ vọng của biến ngẫu nhiên $X$ với điều kiện $S$ bằng trung bình trọng số xác suất có điều kiện các kết cục của $X$
#
# $$
# E(X|S) = \sum_{i=1}^{n}{P(X_i|S)X_i}
# $$

# %% [markdown]
# ## Total Probability Rule for Expected Value
#
# $$
# E(X) = \sum_{i=1}^{n}{E(X|S_i)}
# $$
#
# Trong đó, các điều kiện $S_i$ xung khắc lẫn nhau (`mutually exclusive`) và hợp thành hệ điều kiện tất yếu (`exhaustive scenarios`)

# %% [markdown]
# ## Conditional Variance
#
# **Phương sai có điều kiện** của biến ngẫu nhiên $X$ chính là giá trị kỳ vọng có điều kiện của độ lệch so với giá trị kỳ vọng có điều kiện của bản thân $X$
#
# $$
# \sigma^2(X|S) =\sum_{i=1}^{n}{P(X_i|S)(X_i-E(X_i|S))}
# $$

# %% [markdown]
# # Bayes' Formula and Updating Probability Estimates

# %% [markdown]
# **Công thức Bayes** sử dụng quy tắc tổng xác suất (`total probability rule`)
#
# $$
# P(A) = \sum_{n}{P(A \cap B_n)}
# $$
#
# Nội dung của công thức Bayes được trình bày dưới đây:
#
# $$
# P(A|B) = \dfrac{P(B|A)P(A)}{P(B)}
# $$
#
# ***Chứng minh***
#
# $$
# \dfrac{P(B|A)P(A)}{P(B)} = \dfrac{P(BA)}{P(B)} = \dfrac{P(AB)}{P(B)} = P(A|B)
# $$
#
# Dưới đây là cây quyết định mô tả cho công thức Bayes

# %%
#Tree map
Image(filename = "Pictures/01.png")

# %%
#Summary of Return
Image(filename = "Pictures/02.png")
